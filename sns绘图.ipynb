# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
print(sns.__version__)
# Out:
# 0.11.2

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'exercise', 'flights', 'fmri', 'gammas', 'geyser', 'iris', 'mpg', 'penguins', 'planets', 'taxis', 'tips', 'titanic']

# %%
#分类问题：🐧总类
penguins_data=sns.load_dataset("penguins")

# %%
penguins_data.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
penguins_data.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      342.000000     342.000000         342.000000   342.000000
# mean        43.921930      17.151170         200.915205  4201.754386
# std          5.459584       1.974793          14.061714   801.954536
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.225000      15.600000         190.000000  3550.000000
# 50%         44.450000      17.300000         197.000000  4050.000000
# 75%         48.500000      18.700000         213.000000  4750.000000
# max         59.600000      21.500000         231.000000  6300.000000

# %%
penguins_data.shape
# Out:
# (344, 7)

# %%
tip_data=sns.load_dataset("tips")

# %%
tip_data.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip_data.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.boxplot(data=penguins_data,x="bill_length_mm")
# Out:
# <AxesSubplot:xlabel='bill_length_mm'>

# %%
sns.catplot(data=penguins_data,x="bill_length_mm"·,kind="box")

# %%
sns.boxplot(data=penguins_data,y="bill_length_mm")
# Out:
# <AxesSubplot:ylabel='bill_length_mm'>

# %%
sns.boxplot(data=tip_data,x="tip")
# Out:
# <AxesSubplot:xlabel='tip'>

# %%
sns.displot(data=penguins_data,x="bill_length_mm",bins=50)

# %%
sns.histplot(data=penguins_data,x="bill_length_mm")
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
penguins_data.head(5)
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
sns.displot(data=penguins_data,x="species")

# %%
sns.displot(data=penguins_data,x="species",hue="species")

# %%
sns.displot(data=penguins_data,x="species",hue="species",shrink=0.7)

# %%
sns.countplot(data=penguins_data,x="species")
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [markdown]
# # kde

# %%
sns.displot(x="bill_length_mm",data=penguins_data,kind="kde",rug=True)

# %%
sns.displot(x="bill_length_mm",data=penguins_data,kind="kde",cut=0)

# %%
sns.kdeplot(x="bill_length_mm",data=penguins_data)
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Density'>

# %%
print(np.min(penguins_data["bill_length_mm"]))
print(np.max(penguins_data["bill_length_mm"]))
# Out:
# 32.1
# 59.6

# %%
sns.histplot(data=penguins_data,x="bill_length_mm",kde='true')
# Out:
# <AxesSubplot:xlabel='bill_length_mm', ylabel='Count'>

# %%
sns.displot(data=penguins_data,x="bill_length_mm",bins=50,kde=True)

# %% [markdown]
# 分析双峰分布

# %%
sns.displot(x="bill_length_mm",data=penguins_data,kind="kde",hue="species")

# %% [markdown]
# 分布有偏移的情况

# %%
data_dia=sns.load_dataset("diamonds")

# %%
data_dia.head(5)
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
sns.boxplot(data=data_dia,x="price")
# Out:
# <AxesSubplot:xlabel='price'>

# %%
sns.displot(data=data_dia,x="price")

# %%
sns.displot(data=data_dia,x="price",log_scale=True)

# %% [markdown]
# 利用kde曲线比较训练集和测试集变量分布是否一致

# %%
 from sklearn.model_selection import train_test_split

# %%
 train_data,test_data=train_test_split(data_dia,test_size=0.3,random_state=42)
 sns.displot(data=train_data,x="depth",kind="kde",linewidth=0.5,color="r")
 sns.kdeplot(data=test_data,x="depth",color="g")
# Out:
# <AxesSubplot:xlabel='depth', ylabel='Density'>

# %% [markdown]
# # ecdf

# %%
sns.displot(penguins_data,x="bill_length_mm",kind="ecdf")

# %% [markdown]
# # FacetGrid 特性

# %%
sns.displot(data=penguins_data,x="bill_length_mm",row="sex",hue="species",col="island",kind="kde")

# %% [markdown]
# # 数值变量的关系分析
#
# ## 1.sns.relplot():绘制散点图

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip")

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip",hue="time")

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip",hue="time",style="time")

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip",hue="time",style="time",markers=["o","^"])

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip",hue="size")

# %% [markdown]
# # FacetGrid特性

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip",col="day",col_wrap=2)

# %%
sns.relplot(data=tip_data,x="total_bill",y="tip",hue="time",style="time",kind="line")

# %% [markdown]
# # sns.Implot():分析两个数值变量的线性关系

# %%
 sns.lmplot(data=tip_data,x="total_bill",y="tip")

# %%
 sns.regplot(data=tip_data,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
 sns.residplot(data=tip_data,x="total_bill",y="tip")
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
 sns.lmplot(data=tip_data,x="total_bill",y="tip",row="smoker",col="time",hue="time")

# %% [markdown]
# # sns.displot():绘制两个变量的联合分布

# %%
sns.displot(data=penguins_data,x="bill_length_mm",y="bill_depth_mm")

# %%
sns.displot(data=penguins_data,x="bill_length_mm",y="bill_depth_mm",kind="kde",rug=True)

# %%
sns.displot(data=penguins_data,x="bill_length_mm",y="bill_depth_mm",kind="kde")

# %%
sns.displot(data=penguins_data,x="bill_length_mm",y="bill_depth_mm",kind="kde",thresh=0.2)

# %%
sns.displot(data=penguins_data,x="bill_length_mm",y="bill_depth_mm",kind="kde",thresh=0.5)

# %%
sns.displot(data=penguins_data,x="bill_length_mm",y="bill_depth_mm",kind="kde",thresh=0.2,levels=50)

# %%
sns.displot(data=data_dia,x="price",y="clarity",log_scale=[True,False])

# %%
sns.displot(data=penguins_data,x="island",y="species")

# %%
sns.jointplot(data=tip_data,x="total_bill",y="tip")

# %%
sns.jointplot(data=tip_data,x="total_bill",y="tip",kind="kde")

# %%
sns.jointplot(data=tip_data,x="total_bill",y="tip",kind="hist")

# %%
sns.jointplot(data=tip_data,x="total_bill",y="tip",kind="hex")

# %%
sns.jointplot(data=tip_data,x="total_bill",y="tip",kind="reg")

# %%
sns.jointplot(data=tip_data,x="total_bill",y="tip",hue="sex")

# %%
sns.jointplot(data=penguins_data,x='island',y='species')

# %%
sns.jointplot(data=penguins_data,x='island',y='species',kind="hist")

# %% [markdown]
# 44.50
